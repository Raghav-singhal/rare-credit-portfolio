# %%
# %run main.py {'--nportfolio 20000'} {'--alpha 0.2'}
# Out:
# 100%|██████████| 20/20 [35:58<00:00, 105.50s/it]

# %%
default_prob
# Out:
# array([  9.27354119e-01,   3.73195356e-03,   8.43470081e-04,
#          2.72544531e-04,   1.14400396e-04,   7.38914552e-05,
#          4.23626684e-05,   2.40729708e-05,   1.22487500e-05,
#          8.49931006e-06,   7.42101515e-06,   4.19400089e-06,
#          2.93699030e-06,   1.64377850e-06,   1.17617925e-06,
#          1.09505509e-06,   1.05272788e-06,   6.45021981e-07,
#          6.10387635e-07,   7.01566692e-07,   4.21577405e-07,
#          2.90406844e-07,   1.95541562e-07,   1.37938092e-07,
#          1.48198187e-07,   8.80479648e-08,   5.90490983e-08,
#          5.11175007e-08,   3.80967429e-08,   4.58503276e-08,
#          2.54438697e-08,   1.69274928e-08,   1.15264362e-08,
#          1.60658492e-08,   1.16981542e-08,   8.65549617e-09,
#          6.29087159e-09,   6.72619150e-09,   4.71431897e-09,
#          3.60850550e-09,   2.72998823e-09,   3.38216290e-09,
#          2.26561808e-09,   2.11247374e-09,   1.10671464e-09,
# ...

# %%
default_prob.sum()
# Out:
# 0.93250064592387161

# %%
ndef = IPS.numDefaults(Xn[:,-125:],barriers)
print(ndef)
# Out:
# [ 2  0 25 ...,  0 40  1]
